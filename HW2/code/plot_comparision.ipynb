# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = ['Before Random Erasing', 'After Random Erasing']
y = [80, 85]
plt.bar(x, y)
plt.title('Random Erasing effect comparision')
plt.ylabel('Test Accuracy')
plt.show()
